# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("data.csv", header =1)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.shape
# Out:
# (246, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
df.describe()
# Out:
#         day month  year Temperature   RH   Ws Rain   FFMC  DMC   DC  ISI  BUI  \
# count   246   245   245         245  245  245   245   245  245  245  245  245
# unique   33     5     2          20   63   19    40   174  167  199  107  175
# top       1     7  2012          35   55   14     0  88.9  7.9    8  1.1    3
# freq      8    62   244          29   10   43   133     8    5    5    8    5
#
#         FWI Classes
# count   245       244
# unique  127         9
# top     0.4   fire
# freq     12       131

# %%
## Data cleaning 
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
#  Labelling the dataset
df.loc[:122, "Region"] =0
df.loc[122:, "Region"] = 1

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire        0.0
# 1  not fire        0.0
# 2  not fire        0.0
# 3  not fire        0.0
# 4  not fire        0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.0+ KB

# %%
df['Region'] =df['Region'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 29.0+ KB

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes    Region
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN       1
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN       1

# %%
df = df.dropna().reset_index(drop = True)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %%
df = df.drop(122).reset_index(drop=True)

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122   1     6  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 28.6+ KB

# %%
df.dtypes
# Out:
# day            object
# month          object
# year           object
# Temperature    object
# RH             object
# Ws             object
# Rain           object
# FFMC           object
# DMC            object
# DC             object
# ISI            object
# BUI            object
# FWI            object
# Classes        object
# Region          int64
# dtype: object

# %%
## Chaning datatypes

df[["day" , "month" , "year" , "Temperature" , "RH", "Ws" ]] = df[["day" , "month" , "year" , "Temperature" , "RH", "Ws" ]].astype(int)

# %%
df.dtypes
# Out:
# day             int64
# month           int64
# year            int64
# Temperature     int64
# RH              int64
# Ws              int64
# Rain           object
# FFMC           object
# DMC            object
# DC             object
# ISI            object
# BUI            object
# FWI            object
# Classes        object
# Region          int64
# dtype: object

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18     0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4    5      6  2012           27  77  16     0  64.8    3  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3    0  not fire          0
# 4  0.5  not fire          0

# %%
object = [feature for feature in df.columns if df[feature].dtypes == "O"]
object
# Out:
# ['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes']

# %%
for col in object:
        if col != "Classes":
                df[col] = df[col].astype(float)

# %%
df.dtypes
# Out:
# day              int64
# month            int64
# year             int64
# Temperature      int64
# RH               int64
# Ws               int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes         object
# Region           int64
# dtype: object

# %%
# Saving the cleaned dataset
df.to_csv("cleaned_data.csv", index=False)

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df = df.drop(['day', 'month', 'year'], axis=1)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.Classes.value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df['Classes'] = df['Classes'].astype(str).str.lower().str.strip()  # Remove extra spaces
df['Classes'] = df['Classes'].replace({"not fire": 0, "fire": 1})
# Out:
# C:\Users\adpub\AppData\Local\Temp\ipykernel_1332\2506928355.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Classes'] = df['Classes'].replace({"not fire": 0, "fire": 1})

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df.Classes.value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
df.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 238       1
# 239       1
# 240       1
# 241       1
# 242       1

# %%
plt.style.use('seaborn-v0_8')
df.hist(bins =50, figsize=(20,15))
plt.show()

# %%
percentage = df.Classes.value_counts(normalize=True)*100

# %%
classlabels=["Fire","Not Fire"]
plt.figure(figsize=(12,7))
plt.pie(percentage,labels=classlabels,autopct='%1.1f%%')
plt.title("Pie Chart of Classes")
plt.show()

# %%
df.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(df['FWI'], color="g")
# Out:
# <Axes: ylabel='FWI'>

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
X = df.drop('FWI', axis = 1)
Y = df['FWI']

# %%
X
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  Classes  Region
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4        0       0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9        0       0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7        0       0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7        0       0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9        0       0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...      ...     ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9        1       1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2        0       1
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4        0       1
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1        0       1
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8        0       1
#
# [243 rows x 11 columns]

# %%
Y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((182, 11), (61, 11))

# %%
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# DC              0.390684 -0.236078  0.096576 -0.302341  0.524101  0.868647
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  0.983175
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  0.212582
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %%
plt.figure(figsize=(12,10))
corr = X_train.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.84284248,  0.78307967,  1.29972026, ..., -0.77269802,
#         -1.10431526, -0.98907071],
#        [-0.30175842,  0.64950844, -0.59874754, ..., -0.90344718,
#         -1.10431526,  1.01105006],
#        [ 2.13311985, -2.08870172, -0.21905398, ...,  0.38339978,
#          0.90553851,  1.01105006],
#        ...,
#        [-1.9250106 ,  0.9166509 ,  0.54033314, ..., -1.03419633,
#         -1.10431526, -0.98907071],
#        [ 0.50986767, -0.21870454,  0.16063958, ...,  0.18383528,
#          0.90553851,  1.01105006],
#        [-0.57230045,  0.98343651,  2.05910739, ..., -0.99290713,
#         -1.10431526, -0.98907071]], shape=(182, 11))

# %%
plt.subplot(1,2,1)
sns.boxplot(data = X_train)
plt.subplot(1,2,2)
sns.boxplot(data = X_train_scaled)
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()

lr_model.fit(X_train_scaled, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr_model.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([ 8.31996412e+00,  7.45235640e+00, -8.27841406e-02,  5.16297204e+00,
#         6.54064195e+00,  1.44543845e+00,  2.26547638e+00,  7.46300597e+00,
#         1.92399106e+00,  3.18524625e+00,  7.39775428e-02,  5.94281376e+00,
#         9.48344115e+00,  1.63845627e+01,  1.91363707e+01,  1.31652130e+00,
#         2.08631652e+00, -2.96788725e-03,  6.76169290e+00,  3.14670707e+00,
#         1.27353235e+00,  1.86197099e-01,  6.42186652e+00,  9.35012627e-02,
#         2.10746623e+01,  5.00923944e+00,  5.87895763e+00,  9.98883439e+00,
#         1.27612791e-01,  9.65513073e+00,  6.35241685e+00, -1.60871489e-01,
#         1.02650479e+01,  1.50897365e+01,  1.29812593e+00,  6.24859348e-01,
#         1.82949587e+00,  6.12102707e+00, -2.80701367e-01, -4.94849429e-01,
#         7.03055056e+00,  1.57271366e+00,  8.45730189e+00, -3.51626222e-01,
#         1.51365466e+01,  7.87828752e+00,  7.72962790e+00,  1.07804026e+00,
# ...

# %%
from sklearn.metrics import mean_absolute_error, r2_score

mae_lr = mean_absolute_error(y_pred, Y_test)
mae_lr
# Out:
# 0.46544608000940896

# %%
r2_lr = r2_score(y_pred, Y_test)
r2_lr
# Out:
# 0.9887536295126629

# %%
plt.scatter(Y_test, y_pred)

# %%
from sklearn.linear_model import Lasso

lasso_model = Lasso()

lasso_model.fit(X_train_scaled, Y_train)
# Out:
# Lasso()

# %%
y_pred_lasso = lasso_model.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

mae_lasso = mean_absolute_error(y_pred_lasso, Y_test)
mae_lasso
# Out:
# 1.0816323165898816

# %%
r2_lasso = r2_score(y_pred_lasso, Y_test)
r2_lasso
# Out:
# 0.9345633711703306

# %%
from sklearn.linear_model import Ridge

ridge_model = Ridge()

ridge_model.fit(X_train_scaled, Y_train)
# Out:
# Ridge()

# %%
y_pred_ridge = lasso_model.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

mae_ridge = mean_absolute_error(y_pred_ridge, Y_test)
mae_ridge
# Out:
# 1.0816323165898816

# %%
r2_ridge = r2_score(y_pred_ridge, Y_test)
r2_ridge
# Out:
# 0.9345633711703306

# %%
from sklearn.linear_model import ElasticNet

el_model = ElasticNet()

el_model.fit(X_train_scaled, Y_train)
# Out:
# ElasticNet()

# %%
y_pred_el = lasso_model.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

mae_el = mean_absolute_error(y_pred_el, Y_test)
mae_el
# Out:
# 1.0816323165898816

# %%
r2_el = r2_score(y_pred_el, Y_test)
r2_el
# Out:
# 0.9345633711703306

# %%
from sklearn.linear_model import LassoCV
lassocv = LassoCV(cv = 5)
lassocv.fit(X_train, Y_train)
# Out:
# LassoCV(cv=5)

# %%
y_pred_lassocv = lassocv.predict(X_test_scaled)
# Out:
# c:\Users\adpub\anaconda3\envs\my_ml_env\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LassoCV was fitted with feature names
#   warnings.warn(

# %%
y_pred_lassocv
# Out:
# array([ 8.26157839e-01,  8.94553775e-01, -5.48679878e-01,  2.36178060e-05,
#         5.09234365e-01, -4.51212141e-01, -9.21954827e-03,  6.19400987e-01,
#        -4.02558617e-01, -1.03585590e-01, -6.25521625e-01,  2.13135013e-01,
#         1.14850018e+00,  2.11870438e+00,  2.35220436e+00, -2.87554955e-01,
#        -5.37253624e-01, -8.27047600e-01,  6.35500147e-01,  7.25708308e-03,
#        -1.65284590e-01, -6.02330686e-01,  7.82311997e-01, -5.78140783e-01,
#         3.56774769e+00,  3.33962811e-01,  3.42587807e-01,  9.82596932e-01,
#        -8.30913207e-01,  1.37854103e+00,  4.78893172e-01, -5.95173286e-01,
#         1.15304820e+00,  1.50364612e+00, -2.14945908e-01, -3.69524241e-01,
#        -1.54671215e-01,  2.86457708e-01, -7.63702135e-01, -7.19908897e-01,
#         3.66535753e-01, -1.99057793e-01,  7.73681413e-01, -8.41151496e-01,
#         2.26860965e+00,  7.68556765e-01,  6.39905008e-01, -5.07804063e-01,
# ...

# %%
lassocv.alphas_
# Out:
# array([275.09154269, 256.55129341, 239.26059488, 223.13523156,
#        208.09666376, 194.0716451 , 180.99186576, 168.79361976,
#        157.41749472, 146.80808244, 136.91370903, 127.68618328,
#        119.08056187, 111.05493055, 103.57019992,  96.58991508,
#         90.08007808,  84.00898231,  78.34705807,  73.06672857,
#         68.14227561,  63.5497143 ,  59.26667625,  55.27230063,
#         51.54713256,  48.07302834,  44.83306713,  41.81146846,
#         38.99351542,  36.36548299,  33.91457115,  31.62884256,
#         29.49716443,  27.50915427,  25.65512934,  23.92605949,
#         22.31352316,  20.80966638,  19.40716451,  18.09918658,
#         16.87936198,  15.74174947,  14.68080824,  13.6913709 ,
#         12.76861833,  11.90805619,  11.10549306,  10.35701999,
#          9.65899151,   9.00800781,   8.40089823,   7.83470581,
#          7.30667286,   6.81422756,   6.35497143,   5.92666763,
#          5.52723006,   5.15471326,   4.80730283,   4.48330671,
# ...

# %%
lassocv.intercept_
# Out:
# np.float64(0.6049738592537608)

# %%
lassocv.mse_path_
# Out:
# array([[51.30917612, 65.39074075, 52.19192263, 77.90299066, 43.41480476],
#        [48.47380698, 63.76150305, 49.3971564 , 77.90299066, 39.15309286],
#        [45.95966512, 58.97141667, 46.95502707, 74.23355765, 35.57780273],
#        [43.72815096, 54.80234334, 44.82037059, 68.92798452, 32.59067609],
#        [41.74547414, 51.17359097, 42.95385387, 64.28705782, 30.10684941],
#        [39.98204185, 48.01496454, 41.32121874, 60.22598663, 28.05306909],
#        [38.41192582, 45.26539967, 39.89262425, 56.67090416, 26.36614169],
#        [37.0123978 , 42.87177427, 38.6420743 , 53.55745296, 24.99158867],
#        [35.76352471, 40.78787473, 37.5469197 , 50.82955388, 23.88247862],
#        [34.64781568, 38.97349687, 36.58742484, 48.43833482, 22.99841386],
#        [33.64991436, 37.39366382, 35.74639069, 46.34119858, 22.30465101],
#        [32.75633056, 36.01794585, 35.00882669, 44.50101164, 21.7713381 ],
#        [31.95520623, 34.81986861, 34.36166519, 42.88539825, 21.37285275],
# ...

# %%
plt.scatter(Y_test, y_pred_lassocv)
